# %% [markdown]
# # Sistema IoT Monitoring - Detecção de Anomalias com ML
# ## Enterprise Challenge Sprint 3 - Reply
#
# Este notebook implementa um sistema completo de detecção de anomalias para dados IoT usando múltiplos algoritmos de Machine Learning.
